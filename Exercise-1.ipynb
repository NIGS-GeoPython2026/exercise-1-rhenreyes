# %%
ice_cream_rating = 8

# %%
sleeping_rating = 9

# %%
first_name = input("First Name:")
last_name = input("Last Name:")
# Out:
# First Name: Rhen
# Last Name: Reyes

# %%
my_name = first_name +" "+ last_name
print(my_name)
# Out:
# Rhen Reyes

# %%
happiness_rating= (ice_cream_rating + sleeping_rating)/2
print(happiness_rating)
# Out:
# 8.5

# %%
print(type(ice_cream_rating))
print(type(sleeping_rating),type(first_name),type(last_name), type(my_name), type(happiness_rating))
# Out:
# <class 'int'>
# <class 'int'> <class 'str'> <class 'str'> <class 'NoneType'> <class 'float'>

# %% [markdown]
# Yes. They make sense. None.

# %%
print("My name is " + first_name + " and I give eating ice cream a score of " + str(ice_cream_rating) + " out of 10!")
print("I am " + my_name + " and my sleeping enjoyment rating is " + str(sleeping_rating) + " / 10!")
print("Based on the factors above, my happiness rating is " + str(happiness_rating) + " out of 10, or 85.0 %!")
# Out:
# My name is Rhen and I give eating ice cream a score of 8 out of 10!
# I am Rhen Reyes and my sleeping enjoyment rating is 9 / 10!
# Based on the factors above, my happiness rating is 8.5 out of 10, or 85.0 %!

# %% [markdown]
# Just to try!

# %%
print("My name is %s and I give eating ice cream a score of %d  out of 10!" %(first_name, ice_cream_rating))
# Out:
# My name is Rhen and I give eating ice cream a score of 8  out of 10!
